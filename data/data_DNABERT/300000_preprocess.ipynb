# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
import seqtrainer.dataset_builder as dataset_builder
import seqtrainer.preprocessing as preprocessing
import os
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
current_dir = os.path.abspath('')
original_data_path = os.path.join(current_dir, "..", "data", "original_data")
models_path = os.path.join(current_dir, 'saved-models')
models_metrics_path = os.path.join(current_dir, 'model-metrics')
hpc_dataset_path = os.path.join(current_dir, "..", "hpc", "hpc_datasets")
large_data_path = os.path.join(current_dir, "..", "seqtrainer-data", "sbol_data")

# %%
lb_30000 = pd.read_csv(os.path.join(original_data_path, "frag-rLP5_LB_expression.txt"), sep=" ")
lb_30000 = lb_30000[["fragment", "variation"]]

m9_300000 = pd.read_csv(os.path.join(original_data_path, "frag-rLP5-M9_expression.txt"), sep=" ")
m9_300000 = m9_300000[["fragment", "variation"]]

final = pd.concat([lb_30000, m9_300000], axis=0).reset_index(drop=True)
final.rename(columns={"fragment": "sequence", "variation": "y"}, inplace=True)

# %%
ohe_dna = preprocessing.process_seqs(final, 250, 'sequence')

# %%
df_ohe = pd.DataFrame(ohe_dna)
df_ohe["y"] = final["y"]
df_ohe

# %%
df_ohe.to_csv(os.path.join(dataset_path, "300000_ohe_dna.csv"), index=False)

# %%
final.rename(columns={"y": "target"}, inplace=True)

# %%
final.to_csv(os.path.join(hpc_dataset_path, "dna_seq_target_300000.csv"), index=False)
